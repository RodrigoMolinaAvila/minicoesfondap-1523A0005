# %% [markdown]
# # Espacio Público

# %% [markdown]
# # Nuestro trabajo

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

def create_driver(headless=False):
    """Crea y devuelve una instancia del driver de Chrome."""
    options = Options()
    if headless:
        options.add_argument("--headless")
        options.add_argument("--disable-gpu")  # Recomendado en modo headless
    service = Service()  # Se usa `Service` para evitar advertencias
    driver = webdriver.Chrome(service=service, options=options)
    return driver

# Crear el driver
driver = create_driver(headless=False)

# URL de la página
url = "https://espaciopublico.cl/nuestro-trabajo/"

# Abrir la página
driver.get(url)

# Esperar que cargue la página completamente
time.sleep(2)

# Hacer scroll hasta el final de la página para cargar más contenido
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Esperar la carga de contenido nuevo
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Obtener el HTML después de cargar el contenido
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Encontrar todos los contenedores de proyectos
proyectos = soup.find_all('div', class_='proyecto-loop')

# Lista para almacenar los datos
datos = []

# Iterar sobre cada proyecto
for proyecto in proyectos:
    # Extraer título y enlace desde el segundo <a>
    enlaces = proyecto.find_all('a')
    if len(enlaces) > 1:  # Verificamos que haya al menos dos enlaces
        enlace_tag = enlaces[1]
        titulo_tag = enlace_tag.find('h3')
        titulo = titulo_tag.text.strip() if titulo_tag else "No title"
        enlace = enlace_tag['href']
    else:
        titulo = "No title"
        enlace = "No link"

    # Extraer la fecha
    fecha_tag = proyecto.find('span', class_='proyecto-loop-fecha')
    fecha = fecha_tag.text.strip() if fecha_tag else "No date"

    # Extraer las áreas de estudio
    areas_tag = proyecto.find('span', class_='proyecto-loop-area')
    areas = [a.text.strip() for a in areas_tag.find_all('a')] if areas_tag else ["No areas"]

    # Guardar los datos en un diccionario
    datos.append({
        "Título": titulo,
        "Enlace": enlace,
        "Fecha": fecha,
        "Áreas de estudio": ", ".join(areas)
    })

# Cerrar el navegador
driver.quit()

# Convertir la lista en un DataFrame
df = pd.DataFrame(datos)

# Mostrar el DataFrame
df

# Guardar en CSV (opcional)
# df.to_csv("articulos_espaciopublico.csv", index=False)
# Out:
#                                                 Título  \
# 0                                             No title
# 1                              Perspectivas Económicas
# 2              Personalización de la política en Chile
# 3    Instrumentos económicos y financieros para el ...
# 4    Evolución de la industria del litio en Chile y...
# ..                                                 ...
# 197  «Protección efectiva del consumidor». Document...
# 198  «Opciones de reforma a la seguridad social en ...
# 199  «Participación ciudadana en el sector energéti...
# 200  «Energía y orden territorial». Documento de Re...
# 201  «Debilidades de la regulación chilena sobre la...
#
#                                                 Enlace  \
# 0    https://espaciopublico.cl/areas_de_estudio/seg...
# 1    https://espaciopublico.cl/nuestro_trabajo/pers...
# 2    https://espaciopublico.cl/nuestro_trabajo/la-d...
# 3    https://espaciopublico.cl/nuestro_trabajo/inst...
# 4    https://espaciopublico.cl/nuestro_trabajo/evol...
# ..                                                 ...
# 197  https://espaciopublico.cl/nuestro_trabajo/prot...
# 198  https://espaciopublico.cl/nuestro_trabajo/opci...
# 199  https://espaciopublico.cl/nuestro_trabajo/part...
# 200  https://espaciopublico.cl/nuestro_trabajo/ener...
# 201  https://espaciopublico.cl/nuestro_trabajo/debi...
#
#                        Fecha  \
# 0    30 de noviembre de 2024
# 1     4 de noviembre de 2024
# 2      21 de octubre de 2024
# 3        29 de julio de 2024
# 4        24 de junio de 2024
# ..                       ...
# 197      1 de agosto de 2013
# 198       1 de julio de 2013
# 199       1 de junio de 2013
# 200       1 de junio de 2013
# 201   1 de diciembre de 2012
#
#                                       Áreas de estudio
# 0    Opinión Pública, Seguridad Social (Salud y Pen...
# 1                  Crecimiento Sustentable e Inclusivo
# 2                          Democracia y Anticorrupción
# 3                Sustentabilidad y Recursos Naturales.
# 4                Sustentabilidad y Recursos Naturales.
# ..                                                 ...
# 197                Crecimiento Sustentable e Inclusivo
# 198               Seguridad Social (Salud y Pensiones)
# 199              Sustentabilidad y Recursos Naturales.
# 200              Sustentabilidad y Recursos Naturales.
# 201                        Democracia y Anticorrupción
#
# [202 rows x 4 columns]

# %% [markdown]
# # Prensa

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

def create_driver(headless=False):
    """Crea y devuelve una instancia del driver de Chrome."""
    options = Options()
    if headless:
        options.add_argument("--headless")
        options.add_argument("--disable-gpu")  # Recomendado en modo headless
    service = Service()  # Se usa el `Service` para evitar advertencias
    driver = webdriver.Chrome(service=service, options=options)
    return driver

# Crear el driver
driver = create_driver(headless=False)

# URL de la página que deseas scrapear
url = "https://espaciopublico.cl/categoria/prensa/"

# Abrir la página
driver.get(url)

# Esperar a que la página cargue completamente
time.sleep(2)  # Ajusta este tiempo si es necesario

# Hacer scroll hasta el final de la página para cargar todo el contenido dinámico
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Desplazarse hasta el final de la página
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Esperar a que se cargue el contenido nuevo
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:  # Si no hay más contenido nuevo, salir del bucle
        break
    last_height = new_height

# Obtener el HTML de la página después de cargar todo el contenido
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Encontrar el contenedor de los artículos
articulos_container = soup.select_one("#Content > div > div.sections_group > div.section.Array > div > div > div > div.posts_group.lm_wrapper.grid")

# Lista para almacenar los datos
datos = []

# Verificar si el contenedor fue encontrado
if articulos_container:
    # Encontrar todos los artículos dentro del contenedor
    articulos = articulos_container.find_all('div', class_='post-item isotope-item clearfix post type-post status-publish format-standard has-post-thumbnail')
    
    # Iterar sobre cada artículo
    for articulo in articulos:
        # Extraer el título y el enlace
        titulo_tag = articulo.find('h3', class_='posts-entry-title')
        titulo = titulo_tag.text.strip() if titulo_tag else "No title"
        enlace = titulo_tag.find('a')['href'] if titulo_tag and titulo_tag.find('a') else "No link"
        
        # Extraer la fecha
        fecha_tag = articulo.find('div', class_='post-date')
        fecha = fecha_tag.text.strip() if fecha_tag else "No date"
        
        # Extraer el autor
        autor_tag = articulo.find('div', class_='post-authors')
        autor = autor_tag.find('h5').text.strip() if autor_tag and autor_tag.find('h5') else "No author"
        
        # Extraer el extracto
        extracto_tag = articulo.find('div', class_='post-excerpt')
        extracto = extracto_tag.text.strip() if extracto_tag else "No excerpt"
        
        # Guardar los datos en un diccionario
        datos.append({
            "Título": titulo,
            "Enlace": enlace,
            "Fecha": fecha,
            "Autor": autor,
            "Extracto": extracto
        })
else:
    print("No se encontró el contenedor de artículos.")

# Cerrar el navegador
driver.quit()

# Convertir la lista de datos en un DataFrame
df2 = pd.DataFrame(datos)

# Mostrar el DataFrame
df2

# Guardar el DataFrame en un archivo CSV (opcional)
# df.to_csv("articulos_espaciopublico.csv", index=False)
# Out:
#                                                Título  \
# 0            Reforma de pensiones en su fase decisiva
# 1   Espacio Público y Horizontal lanzan proyecto «...
# 2   ¿Cómo se han insertado jóvenes titulados al me...
# 3                    Avances del acuerdo de pensiones
# 4                             El acuerdo en pensiones
# 5   Espacio Público analiza retornos de la educaci...
# 6   ¿Quién se beneficia? La urgencia de identifica...
# 7             Sistema político: afinar el diagnóstico
# 8                    Claridad en acuerdo en pensiones
# 9              Viejos y nuevos desafíos en integridad
# 10  Inmigrantes indocumentados: el desafío de gest...
# 11        Desafíos pendientes en regulación sanitaria
# 12                           Representación masculina
# 13     Cinco disyuntivas para un acuerdo en pensiones
# 14            Identificar a los beneficiarios finales
# 15         Percepciones sobre licitación de afiliados
# 16                  Percepción ciudadana en pensiones
# 17          Reforma de pensiones: un momento decisivo
# 18                De lo malo, poco; de lo bueno, nada
# 19  Rodrigo Wagner deja asamblea de Espacio Públic...
# 20  Alta demanda para que el actual Congreso concr...
#
#                                                Enlace  \
# 0   https://espaciopublico.cl/reforma-de-pensiones...
# 1   https://espaciopublico.cl/espacio-publico-y-ho...
# 2   https://espaciopublico.cl/como-se-han-insertad...
# 3   https://espaciopublico.cl/avances-del-acuerdo-...
# 4   https://espaciopublico.cl/el-acuerdo-en-pensio...
# 5   https://espaciopublico.cl/espacio-publico-anal...
# 6   https://espaciopublico.cl/quien-se-beneficia-l...
# 7   https://espaciopublico.cl/sistema-politico-afi...
# 8   https://espaciopublico.cl/claridad-en-acuerdo-...
# 9   https://espaciopublico.cl/viejos-y-nuevos-desa...
# 10  https://espaciopublico.cl/inmigrantes-indocume...
# 11  https://espaciopublico.cl/desafios-pendientes-...
# 12  https://espaciopublico.cl/representacion-mascu...
# 13  https://espaciopublico.cl/cinco-disyuntivas-pa...
# 14  https://espaciopublico.cl/identificar-a-los-be...
# 15  https://espaciopublico.cl/percepciones-sobre-l...
# 16  https://espaciopublico.cl/percepcion-ciudadana...
# 17  https://espaciopublico.cl/reforma-de-pensiones...
# 18  https://espaciopublico.cl/de-lo-malo-poco-de-l...
# 19  https://espaciopublico.cl/rodrigo-wagner-deja-...
# 20  https://espaciopublico.cl/alta-demanda-para-qu...
#
#                       Fecha  \
# 0       27 de enero de 2025
# 1       24 de enero de 2025
# 2       23 de enero de 2025
# 3       22 de enero de 2025
# 4       19 de enero de 2025
# 5       16 de enero de 2025
# 6       12 de enero de 2025
# 7        8 de enero de 2025
# 8        4 de enero de 2025
# 9   26 de diciembre de 2024
# 10  23 de diciembre de 2024
# 11  19 de diciembre de 2024
# 12  17 de diciembre de 2024
# 13  15 de diciembre de 2024
# 14  11 de diciembre de 2024
# 15  10 de diciembre de 2024
# 16   4 de diciembre de 2024
# 17   3 de diciembre de 2024
# 18   3 de diciembre de 2024
# 19   1 de diciembre de 2024
# 20   1 de diciembre de 2024
#
#                                                 Autor  \
# 0                                     Paula Benavides
# 1
# 2                  Patricio Domínguez, Martín Latorre
# 3                                     Benjamín García
# 4                                      Andrea Repetto
# 5
# 6                                       Eduardo Engel
# 7                                     Benjamín García
# 8   Paula Benavides, Patricio Domínguez, José De G...
# 9                                     Benjamín García
# 10                                 Patricio Domínguez
# 11                                     Eduardo Bitrán
# 12                                     Javier Sajuria
# 13                                      Eduardo Engel
# 14                                    Benjamín García
# 15                                    Paula Benavides
# 16                                    Benjamín García
# 17  Patricio Domínguez, Paula Benavides, Eduardo E...
# 18                                     Javier Sajuria
# 19
# 20
#
#                                              Extracto
# 0   El camino hacia un acuerdo en materia de pensi...
# 1   Hace más de una década el crecimiento económic...
# 2   El pasado lunes 8 de enero se dieron a conocer...
# 3   Las reformas previsionales son difíciles de tr...
# 4   Los sistemas de pensiones son complejos. Tiene...
# 5   ¿Qué desafíos ha planteado el proceso de expan...
# 6   En los últimos años, hemos presenciado una exp...
# 7   El proyecto de reforma constitucional presenta...
# 8   Señor Director: La necesidad de alcanzar un ac...
# 9   El 2024 estuvo marcado por numerosos casos de ...
# 10  La propuesta del subsecretario Cordero de regu...
# 11  La Ley General de Servicios Sanitarios fue ref...
# 12  Uno de los temas más recurrentes en las discus...
# 13  Se aproximan días cruciales para la aprobación...
# 14  La creación de un registro de beneficiarios fi...
# 15  La reciente encuesta sobre pensiones, de la qu...
# 16  Tras una larga tramitación, la reforma de pens...
# 17  La reciente encuesta realizada por Espacio Púb...
# 18  La última arremetida de un grupo de senadores,...
# 19  Desde este mes, Rodrigo Wagner dejará la asamb...
# 20  La reforma de pensiones se encuentra en plena ...

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

def create_driver(headless=False):
    """Crea y devuelve una instancia del driver de Chrome."""
    options = Options()
    if headless:
        options.add_argument("--headless")
        options.add_argument("--disable-gpu")  # Recomendado en modo headless
    service = Service()  # Se usa el `Service` para evitar advertencias
    driver = webdriver.Chrome(service=service, options=options)
    return driver

def scrape_page(driver, url):
    """Scrapea una página y devuelve los datos de los artículos."""
    driver.get(url)
    time.sleep(0.5)  # Esperar a que la página cargue completamente

    # Hacer scroll hasta el final de la página para cargar todo el contenido dinámico
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)  # Esperar a que se cargue el contenido nuevo
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:  # Si no hay más contenido nuevo, salir del bucle
            break
        last_height = new_height

    # Obtener el HTML de la página después de cargar todo el contenido
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Encontrar el contenedor de los artículos
    articulos_container = soup.select_one("#Content > div > div.sections_group > div.section.Array > div > div > div > div.posts_group.lm_wrapper.grid")

    # Lista para almacenar los datos
    datos = []

    # Verificar si el contenedor fue encontrado
    if articulos_container:
        # Encontrar todos los artículos dentro del contenedor
        articulos = articulos_container.find_all('div', class_='post-item isotope-item clearfix post type-post status-publish format-standard has-post-thumbnail')
        
        # Iterar sobre cada artículo
        for articulo in articulos:
            # Extraer el título y el enlace
            titulo_tag = articulo.find('h3', class_='posts-entry-title')
            titulo = titulo_tag.text.strip() if titulo_tag else "No title"
            enlace = titulo_tag.find('a')['href'] if titulo_tag and titulo_tag.find('a') else "No link"
            
            # Extraer la fecha
            fecha_tag = articulo.find('div', class_='post-date')
            fecha = fecha_tag.text.strip() if fecha_tag else "No date"
            
            # Extraer el autor
            autor_tag = articulo.find('div', class_='post-authors')
            autor = autor_tag.find('h5').text.strip() if autor_tag and autor_tag.find('h5') else "No author"
            
            # Extraer el extracto
            extracto_tag = articulo.find('div', class_='post-excerpt')
            extracto = extracto_tag.text.strip() if extracto_tag else "No excerpt"
            
            # Guardar los datos en un diccionario
            datos.append({
                "Título": titulo,
                "Enlace": enlace,
                "Fecha": fecha,
                "Autor": autor,
                "Extracto": extracto
            })
    else:
        print(f"No se encontró el contenedor de artículos en la página: {url}")

    return datos

# Crear el driver
driver = create_driver(headless=False)

# Lista para almacenar todos los datos de todas las páginas
todos_los_datos = []

# Iterar sobre las páginas (desde la 1 hasta la 103)
for pagina in range(1, 104):  # range(1, 104) para incluir la página 103
    url = f"https://espaciopublico.cl/categoria/prensa/page/{pagina}/"
    print(f"Scrapeando página: {url}")
    datos_pagina = scrape_page(driver, url)
    todos_los_datos.extend(datos_pagina)

# Cerrar el navegador
driver.quit()

# Convertir la lista de datos en un DataFrame
df2 = pd.DataFrame(todos_los_datos)

# Mostrar el DataFrame
df2

# Guardar el DataFrame en un archivo CSV (opcional)
#df2.to_csv("articulos_espaciopublico_todas_las_paginas.csv", index=False)
# Out:
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/1/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/2/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/3/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/4/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/5/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/6/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/7/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/8/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/9/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/10/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/11/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/12/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/13/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/14/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/15/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/16/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/17/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/18/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/19/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/20/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/21/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/22/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/23/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/24/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/25/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/26/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/27/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/28/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/29/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/30/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/31/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/32/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/33/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/34/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/35/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/36/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/37/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/38/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/39/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/40/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/41/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/42/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/43/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/44/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/45/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/46/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/47/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/48/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/49/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/50/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/51/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/52/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/53/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/54/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/55/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/56/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/57/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/58/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/59/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/60/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/61/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/62/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/63/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/64/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/65/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/66/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/67/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/68/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/69/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/70/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/71/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/72/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/73/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/74/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/75/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/76/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/77/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/78/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/79/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/80/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/81/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/82/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/83/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/84/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/85/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/86/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/87/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/88/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/89/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/90/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/91/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/92/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/93/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/94/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/95/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/96/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/97/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/98/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/99/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/100/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/101/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/102/
# Scrapeando página: https://espaciopublico.cl/categoria/prensa/page/103/
#                                                  Título  \
# 0              Reforma de pensiones en su fase decisiva
# 1     Espacio Público y Horizontal lanzan proyecto «...
# 2     ¿Cómo se han insertado jóvenes titulados al me...
# 3                      Avances del acuerdo de pensiones
# 4                               El acuerdo en pensiones
# ...                                                 ...
# 2139  Proyecto para fortalecer el Sernac acoge varia...
# 2140  Marcela Ríos: “Relación de la ciudadanía con l...
# 2141  “El fin de los clubes cerrados: Cómo reducir l...
# 2142              «SEMINARIO SOBRE SEGREGACIÓN ESCOLAR»
# 2143  James Robinson en el lanzamiento de Espacio Pú...
#
#                                                  Enlace  \
# 0     https://espaciopublico.cl/reforma-de-pensiones...
# 1     https://espaciopublico.cl/espacio-publico-y-ho...
# 2     https://espaciopublico.cl/como-se-han-insertad...
# 3     https://espaciopublico.cl/avances-del-acuerdo-...
# 4     https://espaciopublico.cl/el-acuerdo-en-pensio...
# ...                                                 ...
# 2139  https://espaciopublico.cl/proyecto-para-fortal...
# 2140  https://espaciopublico.cl/marcela-rios-relacio...
# 2141  https://espaciopublico.cl/el-fin-de-los-clubes...
# 2142  https://espaciopublico.cl/seminario-sobre-segr...
# 2143  https://espaciopublico.cl/james-robinson-en-el...
#
#                         Fecha                               Autor  \
# 0         27 de enero de 2025                     Paula Benavides
# 1         24 de enero de 2025
# 2         23 de enero de 2025  Patricio Domínguez, Martín Latorre
# 3         22 de enero de 2025                     Benjamín García
# 4         19 de enero de 2025                      Andrea Repetto
# ...                       ...                                 ...
# 2139       5 de junio de 2014
# 2140       28 de mayo de 2014
# 2141       12 de mayo de 2014
# 2142  19 de diciembre de 2013
# 2143      6 de agosto de 2013
#
#                                                Extracto
# 0     El camino hacia un acuerdo en materia de pensi...
# 1     Hace más de una década el crecimiento económic...
# 2     El pasado lunes 8 de enero se dieron a conocer...
# 3     Las reformas previsionales son difíciles de tr...
# 4     Los sistemas de pensiones son complejos. Tiene...
# ...                                                 ...
# 2139  La iniciativa del Ejecutivo le confiere mayore...
# 2140  La cientista política y directora de Espacio P...
# 2141  Este lunes 12 de mayo a las 9:00 hrs. en el Ce...
# 2142  Espacio Público presentó los principales resul...
# 2143  James Robinson planteó que el desarrollo de Ch...
#
# [2144 rows x 5 columns]

# %% [markdown]
# # Corpus

# %%
import pandas as pd

# Lista de DataFrames
dfs = [df, df2]

# Concatenar todos los DataFrames en uno solo
ep = pd.concat(dfs, ignore_index=True)

# Mostrar el DataFrame resultante
ep
# Out:
#                                                  Título  \
# 0                                              No title
# 1                               Perspectivas Económicas
# 2               Personalización de la política en Chile
# 3     Instrumentos económicos y financieros para el ...
# 4     Evolución de la industria del litio en Chile y...
# ...                                                 ...
# 2341  Proyecto para fortalecer el Sernac acoge varia...
# 2342  Marcela Ríos: “Relación de la ciudadanía con l...
# 2343  “El fin de los clubes cerrados: Cómo reducir l...
# 2344              «SEMINARIO SOBRE SEGREGACIÓN ESCOLAR»
# 2345  James Robinson en el lanzamiento de Espacio Pú...
#
#                                                  Enlace  \
# 0     https://espaciopublico.cl/areas_de_estudio/seg...
# 1     https://espaciopublico.cl/nuestro_trabajo/pers...
# 2     https://espaciopublico.cl/nuestro_trabajo/la-d...
# 3     https://espaciopublico.cl/nuestro_trabajo/inst...
# 4     https://espaciopublico.cl/nuestro_trabajo/evol...
# ...                                                 ...
# 2341  https://espaciopublico.cl/proyecto-para-fortal...
# 2342  https://espaciopublico.cl/marcela-rios-relacio...
# 2343  https://espaciopublico.cl/el-fin-de-los-clubes...
# 2344  https://espaciopublico.cl/seminario-sobre-segr...
# 2345  https://espaciopublico.cl/james-robinson-en-el...
#
#                         Fecha  \
# 0     30 de noviembre de 2024
# 1      4 de noviembre de 2024
# 2       21 de octubre de 2024
# 3         29 de julio de 2024
# 4         24 de junio de 2024
# ...                       ...
# 2341       5 de junio de 2014
# 2342       28 de mayo de 2014
# 2343       12 de mayo de 2014
# 2344  19 de diciembre de 2013
# 2345      6 de agosto de 2013
#
#                                        Áreas de estudio Autor  \
# 0     Opinión Pública, Seguridad Social (Salud y Pen...   NaN
# 1                   Crecimiento Sustentable e Inclusivo   NaN
# 2                           Democracia y Anticorrupción   NaN
# 3                 Sustentabilidad y Recursos Naturales.   NaN
# 4                 Sustentabilidad y Recursos Naturales.   NaN
# ...                                                 ...   ...
# 2341                                                NaN
# 2342                                                NaN
# 2343                                                NaN
# 2344                                                NaN
# 2345                                                NaN
#
#                                                Extracto
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2341  La iniciativa del Ejecutivo le confiere mayore...
# 2342  La cientista política y directora de Espacio P...
# 2343  Este lunes 12 de mayo a las 9:00 hrs. en el Ce...
# 2344  Espacio Público presentó los principales resul...
# 2345  James Robinson planteó que el desarrollo de Ch...
#
# [2346 rows x 6 columns]

# %%
ep.columns
# Out:
# Index(['Título', 'Enlace', 'Fecha', 'Áreas de estudio', 'Autor', 'Extracto'], dtype='object')

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import time

def create_driver(headless=False):
    """Crea y devuelve una instancia del driver de Chrome."""
    options = Options()
    if headless:
        options.add_argument("--headless")
        options.add_argument("--disable-gpu")  # Recomendado en modo headless
    service = Service()  # Se usa el `Service` para evitar advertencias
    driver = webdriver.Chrome(service=service, options=options)
    return driver

driver = create_driver(headless=False)

# Cargar el DataFrame
ep2 = ep.copy() 

# Crear la columna "Corpus" si no existe
if 'Corpus' not in ep2.columns:
    ep2['Corpus'] = None
    ep2["Tipo"] = None

# Función para extraer el corpus
def extract_corpus(url):
    driver.get(url)
    time.sleep(1)  # Esperar a que la página cargue

    try:
        # Intentar extraer el corpus del primer formato
        corpus_container = driver.find_element(By.CSS_SELECTOR, "#Content > div > div.sections_group > div > div.section.mcb-section.mcb-section-3dd2c9463.content-sidebar > div > div.wrap.mcb-wrap.mcb-wrap-2cfe5bd5f.one.valign-top.clearfix > div > div.column.mcb-column.mcb-item-xsufmzocp.one.column_column > div")
        paragraphs = corpus_container.find_elements(By.TAG_NAME, "p")
        corpus = "\n".join([p.text for p in paragraphs])
        return corpus
    except NoSuchElementException:
        try:
            # Intentar extraer el corpus del segundo formato (ficha-proyectos)
            corpus_container = driver.find_element(By.CSS_SELECTOR, "div.ficha-proyectos h5")
            paragraphs = corpus_container.find_elements(By.TAG_NAME, "p")
            corpus = "\n".join([p.text for p in paragraphs])
            return corpus
        except NoSuchElementException:
            return None

# Función para extraer título, áreas de estudio, autor y tipo
def extract_attributes(url):
    driver.get(url)
    time.sleep(1)  # Esperar a que la página cargue

    attributes = {
        'Título': None,
        'Áreas de estudio': None,
        'Autor': None,
        'Tipo': None
    }

    try:
        # Intentar extraer el título del primer formato
        title_element = driver.find_element(By.CSS_SELECTOR, "#Content > div > div.sections_group > div > div.section.mcb-section.mcb-section-3dd2c9463.content-sidebar > div > div.wrap.mcb-wrap.mcb-wrap-a64fdbaf3.three-fifth.seccion-areas.valign-top.clearfix > div > div.column.mcb-column.mcb-item-1a0633259.one.column_column.column-margin-0px > div > h3")
        attributes['Título'] = title_element.text
    except NoSuchElementException:
        try:
            # Intentar extraer el título del segundo formato (ficha-proyectos)
            title_element = driver.find_element(By.CSS_SELECTOR, "div.ficha-proyectos h3")
            attributes['Título'] = title_element.text
        except NoSuchElementException:
            pass

    try:
        # Intentar extraer áreas de estudio del primer formato
        areas_element = driver.find_element(By.CSS_SELECTOR, "#Content > div > div.sections_group > div > div.section.mcb-section.mcb-section-3dd2c9463.content-sidebar > div > div.wrap.mcb-wrap.mcb-wrap-a64fdbaf3.three-fifth.seccion-areas.valign-top.clearfix > div > div.column.mcb-column.mcb-item-1a0633259.one.column_column.column-margin-0px > div > span.area-post")
        attributes['Áreas de estudio'] = areas_element.text
    except NoSuchElementException:
        try:
            # Intentar extraer áreas de estudio del segundo formato (ficha-proyectos)
            areas_element = driver.find_element(By.CSS_SELECTOR, "span.ficha-proyecto-area")
            attributes['Áreas de estudio'] = areas_element.text.replace("Área de estudio: ", "")
        except NoSuchElementException:
            pass

    try:
        # Intentar extraer autor del primer formato
        author_element = driver.find_element(By.CSS_SELECTOR, "#Content > div > div.sections_group > div > div.section.mcb-section.mcb-section-3dd2c9463.content-sidebar > div > div.wrap.mcb-wrap.mcb-wrap-a64fdbaf3.three-fifth.seccion-areas.valign-top.clearfix > div > div.column.mcb-column.mcb-item-1a0633259.one.column_column.column-margin-0px > div > div.column_attr.clearfix.post-ficha > span.autores-post")
        attributes['Autor'] = author_element.text
    except NoSuchElementException:
        try:
            # Intentar extraer autor del segundo formato (ficha-proyectos)
            author_elements = driver.find_elements(By.CSS_SELECTOR, "span.ficha-proyecto-equipo ul li a")
            authors = [author.text for author in author_elements]
            attributes['Autor'] = ", ".join(authors)
        except NoSuchElementException:
            pass

    try:
        # Intentar extraer tipo del segundo formato (ficha-proyectos)
        tipo_element = driver.find_element(By.CSS_SELECTOR, "span.ficha-proyecto-tipo")
        attributes['Tipo'] = tipo_element.text.replace("Tipo: ", "")
    except NoSuchElementException:
        pass

    return attributes

# Iterar sobre cada fila del DataFrame
for index, row in ep2.iterrows():
    url = row['Enlace']
    
    # Extraer el corpus
    corpus = extract_corpus(url)
    if corpus:
        ep2.at[index, 'Corpus'] = corpus
    
    # Extraer y actualizar atributos si están vacíos o son NaN
    attributes = extract_attributes(url)
    for key, value in attributes.items():
        if pd.isna(row[key]) or row[key] == 'No title':
            ep2.at[index, key] = value

# Guardar el DataFrame actualizado
# ep2.to_csv('ep_actualizado.csv', index=False)

# Cerrar el navegador
driver.quit()

ep2
# Out:
#                                                  Título  \
# 0                                                  None
# 1                               Perspectivas Económicas
# 2               Personalización de la política en Chile
# 3     Instrumentos económicos y financieros para el ...
# 4     Evolución de la industria del litio en Chile y...
# ...                                                 ...
# 2341  Proyecto para fortalecer el Sernac acoge varia...
# 2342  Marcela Ríos: “Relación de la ciudadanía con l...
# 2343  “El fin de los clubes cerrados: Cómo reducir l...
# 2344              «SEMINARIO SOBRE SEGREGACIÓN ESCOLAR»
# 2345  James Robinson en el lanzamiento de Espacio Pú...
#
#                                                  Enlace  \
# 0     https://espaciopublico.cl/areas_de_estudio/seg...
# 1     https://espaciopublico.cl/nuestro_trabajo/pers...
# 2     https://espaciopublico.cl/nuestro_trabajo/la-d...
# 3     https://espaciopublico.cl/nuestro_trabajo/inst...
# 4     https://espaciopublico.cl/nuestro_trabajo/evol...
# ...                                                 ...
# 2341  https://espaciopublico.cl/proyecto-para-fortal...
# 2342  https://espaciopublico.cl/marcela-rios-relacio...
# 2343  https://espaciopublico.cl/el-fin-de-los-clubes...
# 2344  https://espaciopublico.cl/seminario-sobre-segr...
# 2345  https://espaciopublico.cl/james-robinson-en-el...
#
#                         Fecha  \
# 0     30 de noviembre de 2024
# 1      4 de noviembre de 2024
# 2       21 de octubre de 2024
# 3         29 de julio de 2024
# 4         24 de junio de 2024
# ...                       ...
# 2341       5 de junio de 2014
# 2342       28 de mayo de 2014
# 2343       12 de mayo de 2014
# 2344  19 de diciembre de 2013
# 2345      6 de agosto de 2013
#
#                                        Áreas de estudio  \
# 0     Opinión Pública, Seguridad Social (Salud y Pen...
# 1                   Crecimiento Sustentable e Inclusivo
# 2                           Democracia y Anticorrupción
# 3                 Sustentabilidad y Recursos Naturales.
# 4                 Sustentabilidad y Recursos Naturales.
# ...                                                 ...
# 2341                Crecimiento Sustentable e Inclusivo
# 2342                        Democracia y Anticorrupción
# 2343                        Jóvenes, Educación y Empleo
# 2344                        Jóvenes, Educación y Empleo
# 2345                        Democracia y Anticorrupción
#
#                                                   Autor  \
# 0
# 1     Patricio Domínguez, Paula Benavides, Eduardo B...
# 2       Javier Sajuria, Julieta Suárez-Cao, Matías Piña
# 3
# 4
# ...                                                 ...
# 2341
# 2342
# 2343
# 2344
# 2345
#
#                                                Extracto  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2341  La iniciativa del Ejecutivo le confiere mayore...
# 2342  La cientista política y directora de Espacio P...
# 2343  Este lunes 12 de mayo a las 9:00 hrs. en el Ce...
# 2344  Espacio Público presentó los principales resul...
# 2345  James Robinson planteó que el desarrollo de Ch...
#
#                                                  Corpus                   Tipo
# 0                                                  None                   None
# 1     La discusión por el desarrollo económico y los...      Tipo:\nPropuestas
# 2     En los últimos años, la ciudadanía se ha acost...      Tipo:\nPropuestas
# 3     Con el objetivo de aportar en la elaboración d...  Tipo:\nMinuta técnica
# 4     La industria mundial del litio experimentó un ...  Tipo:\nMinuta técnica
# ...                                                 ...                    ...
# 2341  \nEl proyecto para fortalecer el Sernac, envia...                   None
# 2342  \nEn medio del dinámico debate público que se ...                   None
# 2343  \nBajo el objetivo de hacer propuestas para fo...                   None
# 2344  \nEspacio Público presentó los principales res...                   None
# 2345  \nCon la masiva asistencia de académicos, auto...                   None
#
# [2346 rows x 8 columns]

# %%
ep2.to_excel("Espacio_publico.xlsx", index=False)
