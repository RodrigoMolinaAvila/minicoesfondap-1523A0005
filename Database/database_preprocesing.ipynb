# %%
import pandas as pd

file_path = r'C:\Users\Rodrigo\Desktop\MiniCOES\minicoesfondap-1523A0005\Database\01_database_think_tanks.xlsx'
df = pd.read_excel(file_path)

df.head()
# Out:
#    ID Think Tank Tipo de Think Tank Orientación Política             Autor  \
# 0   1        LyD                NaN              Derecha  Francisco Garcés
# 1   2        LyD                NaN              Derecha  Francisco Garcés
# 2   3        LyD                NaN              Derecha  Francisco Garcés
# 3   4        LyD                NaN              Derecha  Francisco Garcés
# 4   5        LyD                NaN              Derecha     Ricardo Matte
#
#                                               Título Fecha de Publicación  \
# 0  India: Necesidad de Reformas Estructurales par...  2011-01-01 00:00:00
# 1  Bolivia: Turbulencia Política Incesante, Auge ...  2011-01-01 00:00:00
# 2  México: Potencial Económico Continúa a la Espe...  2011-01-01 00:00:00
# 3            Panamá: Reformas Económicas y Expansión  2011-01-01 00:00:00
# 4  Índice de Libertad Económica: Señales de Alert...  2011-01-01 00:00:00
#
#   Medio de Comunicación Corpus             Producto  \
# 0                   NaN    NaN  Coyuntura Económica
# 1                   NaN    NaN  Coyuntura Económica
# 2                   NaN    NaN  Coyuntura Económica
# 3                   NaN    NaN  Coyuntura Económica
# 4                   NaN    NaN  Coyuntura Económica
#
#                           Enlace
# 0  Wayback Machine (archive.org)
# 1  Wayback Machine (archive.org)
# 2  Wayback Machine (archive.org)
# 3  Wayback Machine (archive.org)
# 4  Wayback Machine (archive.org)

# %%
unique_think_tanks = df['Think Tank'].unique()
print(unique_think_tanks)
# Out:
# ['LyD' 'IES' 'FPP' 'CEP' 'Nodo XXI' 'Fundación Sol' 'Chile 21'
#  'Espacio Público' 'Centro de Estudios del Desarrollo'
#  'Fundación Jaime Guzmán' 'Centro Democracia y Comunidad' 'La Casa Común'
#  'Observatorio de Políticas Económicas' 'Rumbo Colectivo'
#  'Instituto Igualdad' 'ICAL' 'Horizonte Ciudadano' 'Horizontal'
#  'CLAPES-UC' 'Signos Uandes' 'Instituto ResPública' 'Pivotes'
#  'Instituto Libertad' 'Ideas Republicanas' 'Idea País']

# %%
# Mapeo de think tanks a su tipo
think_tank_mapping = {
    # Transversales (Izquierda)
    'Fundación Sol': 'Transversal',
    'Nodo XXI': 'Transversal',
    'Chile 21': 'Transversal',
    'Espacio Público': 'Transversal',
    'Centro de Estudios del Desarrollo': 'Transversal',
    'Horizonte Ciudadano': 'Transversal',

    # De Partido (Izquierda)
    'Rumbo Colectivo': 'De Partido',
    'Instituto Igualdad': 'De Partido',
    'Centro Democracia y Comunidad': 'De Partido',
    'ICAL': 'De Partido',
    'Observatorio de Políticas Económicas': 'De Partido',

    # Semi Difuntos
    'La Casa Común': 'Semi Difunto',

    # Transversales (Derecha)
    'LyD': 'Transversal',
    'CEP': 'Transversal',
    'Pivotes': 'Transversal',
    'IES': 'Transversal',
    'Idea País': 'Transversal',
    'Instituto ResPública': 'Transversal',
    'FPP': 'Transversal',

    # De Partido (Derecha)
    'Fundación Jaime Guzmán': 'De Partido',
    'Horizontal': 'De Partido',
    'Ideas Republicanas': 'De Partido',
    'Instituto Libertad': 'De Partido',

    # Universidades
    'CLAPES-UC': 'Universidad',
    'Signos Uandes': 'Universidad'
}

# Crear la nueva columna "Tipo de Think Tank"
df['Tipo de Think Tank'] = df['Think Tank'].map(think_tank_mapping)

# %%
df.to_excel('01_database_think_tanks_updated.xlsx', index=False)
