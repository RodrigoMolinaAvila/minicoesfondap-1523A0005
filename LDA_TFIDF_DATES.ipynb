# %%
import pandas as pd
import numpy as np
import re
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# --- Funciones de limpieza ---
def remove_numbers(text):
    return " ".join(re.sub(r"[0-9]", " ", text).split())

def remove_unprintable_(text):
    printable = set(string.printable + "ñáéíóúüÑÁÉÍÓÚÜ")
    return "".join(filter(lambda x: x in printable, text))

def remove_punctuation(text):
    pattern = re.compile(r"[^\w\sáéíóúüñÁÉÍÓÚÜÑ]")
    return re.sub(" +", " ", pattern.sub(" ", text))

def reduce_spam(text):
    text = re.sub(r"(\w+)(\s+\1){2,}", r"\1", text)
    text = re.sub(r"(\w+\s+\w+)(\s+\1){2,}", r"\1", text)
    return text

def remove_vowels_accents(text):
    return (
        text.replace("á", "a").replace("é", "e")
            .replace("í", "i").replace("ó", "o")
            .replace("ú", "u").replace("ü", "u")
    )

def remove_stopwords(text, stopwords_list):
    return " ".join([word for word in text.split() if word not in stopwords_list])

def clean_text(text, stopwords_list):
    text = text.lower()
    text = remove_numbers(text)
    text = remove_unprintable_(text)
    text = remove_punctuation(text)
    text = reduce_spam(text)
    text = remove_stopwords(text, stopwords_list)
    text = remove_vowels_accents(text)
    return text.strip()

# %%
# --- Carga del corpus ---
df = pd.read_excel("01_bbdd_think_tanks.xlsx")  # Ajusta la ruta real

# --- Carga de stopwords mejoradas ---
with open("stopwords.txt", "r", encoding="utf-8") as f:
    stopwords_list = [line.strip().lower() for line in f if line.strip()]

# --- Preprocesamiento ---
df = df.dropna(subset=["Corpus"])
df["FechaPublicación"] = pd.to_datetime(df["FechaPublicación"], errors="coerce")
df["TextoLimpio"] = df["Corpus"].apply(lambda x: clean_text(str(x), stopwords_list))

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

def compute_lda_and_tfidf(documents, n_topics=6, n_top_words=10):
    if len(documents) < 3:
        return [], []

    # LDA
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(documents)
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda_matrix = lda.fit_transform(X)
    topics = [list(np.where(row > 0.1)[0]) for row in lda_matrix]

    # TF-IDF
    tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2))
    X_tfidf = tfidf_vectorizer.fit_transform(documents)
    tfidf_sum = X_tfidf.sum(axis=0).A1
    feature_names = tfidf_vectorizer.get_feature_names_out()
    top_indices = tfidf_sum.argsort()[::-1][:n_top_words]
    tfidf_top_words = [feature_names[i] for i in top_indices]

    return topics, tfidf_top_words

# %%
def aplicar_modelado_por_grupo(df, columna_categoria, n_topics=6):
    df_result = df.copy()
    col_lda = f"LDA_Topics_{columna_categoria}"
    col_tfidf = f"TFIDF_TopWords_{columna_categoria}"
    
    df_result[col_lda] = None
    df_result[col_tfidf] = None

    for (grupo, fecha), subgrupo in df.groupby([columna_categoria, "FechaPublicación"]):
        textos = subgrupo["TextoLimpio"].dropna().tolist()
        textos = [t for t in textos if len(t.split()) >= 3]
        if len(textos) < 3:
            continue

        try:
            lda_topics, tfidf_words = compute_lda_and_tfidf(textos, n_topics=n_topics)
            idx = subgrupo.index
            df_result.loc[idx, col_lda] = [lda_topics] * len(idx)
            df_result.loc[idx, col_tfidf] = [tfidf_words] * len(idx)
        except Exception as e:
            print(f"Error en grupo {grupo} - {fecha}: {e}")
            continue

    return df_result

# %%
# Aplicar por Think Tank
df = aplicar_modelado_por_grupo(df, "Think Tank")

# Aplicar por Orientación Política
df = aplicar_modelado_por_grupo(df, "Orientación Política")
# Out:
# Error en grupo (CDC, 2021-11-26 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2021-12-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2021-12-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2022-01-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2022-03-06 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2022-09-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CDC, 2022-10-14 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2022-02-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2022-06-15 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2022-07-25 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2022-08-04 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-03-15 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-03-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-04-19 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-05-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-05-11 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-06-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-07-04 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2023-09-25 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2024-04-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2024-07-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CED, 2024-12-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1981-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1982-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1986-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1988-08-23 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1988-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1988-11-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1990-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1991-04-23 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1991-05-06 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1992-07-09 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1992-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1993-04-28 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1994-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1995-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1996-08-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1996-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1997-01-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 1997-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2000-04-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2000-10-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2001-05-28 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2001-08-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2001-09-04 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2001-10-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2002-07-11 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2002-09-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2004-01-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2004-04-26 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (15, 15) + inhomogeneous part.
# Error en grupo (CEP, 2004-05-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2004-05-11 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2004-07-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2005-06-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2005-06-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2005-06-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2005-06-14 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2005-08-25 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-01-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-06-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-06-14 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-07-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-07-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2006-07-31 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2007-07-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2007-10-25 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (20, 20) + inhomogeneous part.
# Error en grupo (CEP, 2008-09-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2008-09-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-01-09 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-01-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-05-25 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-06-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-08-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2009-12-18 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (12, 12) + inhomogeneous part.
# Error en grupo (CEP, 2010-08-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2011-11-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2012-09-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2012-10-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2013-03-18 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2013-07-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2013-08-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2014-06-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2015-03-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2015-03-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2015-03-23 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2016-06-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2016-11-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-03-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-03-22 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (12, 12) + inhomogeneous part.
# Error en grupo (CEP, 2017-06-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-07-06 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-07-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-11-09 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2017-11-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-01-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-03-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-04-16 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-05-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-09-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-11-11 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-11-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2018-11-15 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-01-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-06-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-08-05 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-10-26 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-10-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-05 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-06 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-20 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-11-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-12-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2019-12-18 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-01-09 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-01-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-01-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-01-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-01-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-03-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-03-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-04-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-04-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-04-28 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-04-30 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-05-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-05-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-05-28 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-05-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-06-03 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-06-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-06-25 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-07-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-07-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-07-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-08-06 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-08-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-08-18 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-08-26 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-02 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-09 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-22 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-09-23 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-10-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-10-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-10-08 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-10-15 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-10-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-11-04 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (7, 7) + inhomogeneous part.
# Error en grupo (CEP, 2020-11-11 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-11-12 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (12, 12) + inhomogeneous part.
# Error en grupo (CEP, 2020-11-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-11-18 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-11-19 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-12-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-12-13 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-12-15 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2020-12-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-01-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-01-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-01-12 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-01-19 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-02-21 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-03-14 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-03-23 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-03-24 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-03-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-04-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-04-29 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-05-07 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-05-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-06-01 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-06-10 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-06-17 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021-06-27 00:00:00): setting an array element with a sequence.
# Error en grupo (CEP, 2021
17 00:00:00): setting an array element with a sequence.
# Error en grupo (Espacio Público, 2018-04-30 00:00:00): setting an array element with a sequence.
# ...
# Error en grupo (Izquierda, 2023-07-11 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-12 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-14 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-16 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-19 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-24 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-29 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-07-31 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-05 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-14 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-16 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-24 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-25 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-28 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-29 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-08-31 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-02 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-07 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-12 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-22 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-25 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-27 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-09-28 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-02 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-07 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-18 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-25 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-10-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-28 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-11-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-07 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-12 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-15 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2023-12-27 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-01-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-01-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-01-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-01-11 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (7, 7) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-01-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-01-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-02-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-18 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-25 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-03-27 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-04 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-16 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-04-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-01 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (11, 11) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-05-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-15 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-21 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4, 4) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-05-22 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-05-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-01 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (6, 6) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-06-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-04 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-05 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-18 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-06-27 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-09 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-10 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (3, 3) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-07-12 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-15 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-22 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-29 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-07-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-05 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-07 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-12 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-14 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-15 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-19 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-26 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-27 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-08-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-01 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-04 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-05 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-22 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-09-29 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-01 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (8, 8) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-10-02 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-04 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-06 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-07 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-09 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-14 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-16 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-18 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-28 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-10-29 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-03 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-11 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-18 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-22 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-25 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-11-28 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-02 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-09 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-15 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-16 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-17 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-18 00:00:00): setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (22, 22) + inhomogeneous part.
# Error en grupo (Izquierda, 2024-12-23 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2024-12-30 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-02 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-08 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-10 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-13 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-20 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-21 00:00:00): setting an array element with a sequence.
# Error en grupo (Izquierda, 2025-01-26 00:00:00): setting an array element with a sequence.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30240 entries, 0 to 31646
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   30240 non-null  int64
#  1   Think Tank                           30240 non-null  object
#  2   Tipo de Think Tank                   30240 non-null  object
#  3   Orientación Política                 30240 non-null  object
#  4   Autor                                13818 non-null  object
#  5   Título                               30237 non-null  object
#  6   FechaPublicación                     30068 non-null  datetime64[ns]
#  7   Unnamed: 7                           75 non-null     object
#  8   Medio                                5762 non-null   object
#  9   Corpus                               30240 non-null  object
#  10  Producto                             17441 non-null  object
#  11  Enlace                               30231 non-null  object
#  12  EnlacePDF                            569 non-null    object
#  13  FechaPDF                             653 non-null    object
#  14  CorpusPDF_x                          569 non-null    object
#  15  FechaPubPDF_x                        537 non-null    datetime64[ns]
#  16  FechaPubPDF_y                        166 non-null    datetime64[ns]
#  17  CorpusPDF_y                          180 non-null    object
#  18  TextoLimpio                          30240 non-null  object
#  19  LDA_Topics_Think Tank                0 non-null      float64
#  20  TFIDF_TopWords_Think Tank            0 non-null      float64
#  21  LDA_Topics_Tipo de Think Tank        0 non-null      float64
#  22  TFIDF_TopWords_Tipo de Think Tank    0 non-null      float64
#  23  LDA_Topics_Orientación Política      0 non-null      float64
#  24  TFIDF_TopWords_Orientación Política  0 non-null      float64
# dtypes: datetime64[ns](3), float64(6), int64(1), object(15)
# memory usage: 7.0+ MB
